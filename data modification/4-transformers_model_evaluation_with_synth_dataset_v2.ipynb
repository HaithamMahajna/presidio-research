# %%
from pathlib import Path
from pprint import pprint
from collections import Counter
from typing import Dict, List
import json
from copy import deepcopy

from presidio_evaluator import InputSample
from presidio_evaluator.evaluation import Evaluator, ModelError
from presidio_evaluator.models import PresidioAnalyzerWrapper
from presidio_evaluator.experiment_tracking import get_experiment_tracker

import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
dataset_name = "synth_dataset_v2.json"
dataset = InputSample.read_dataset_json(Path(Path.cwd().parent, "data", dataset_name))
dataset = Evaluator.align_entity_types(
    deepcopy(dataset), entities_mapping=PresidioAnalyzerWrapper.presidio_entities_map
)
print(len(dataset))
# Out:
# tokenizing input: 100%|██████████| 1500/1500 [00:30<00:00, 49.56it/s]
# 1500

# %%
presidio_entities_map = dict(
  FIRSTNAME=  "PERSON",
  LASTNAME = "PERSON",
  MIDDLENAME="PERSON",
  FULLNAME = "PERSON",
  PATIENT="PERSON",
  STAFF="PERSON",
  PER="PERSON",
  HCW="PERSON",
  PERSON = "PERSON",



  DATE="DATE_TIME",
  TIME="DATE_TIME",
  DOB="DATE_TIME" ,
  DATE_TIME = "DATE_TIME",

  EMAIL="EMAIL_ADDRESS",
  EMAIL_ADDRESS="EMAIL_ADDRESS",

  PREFIX="TITLE",
  TITLE = "TITLE",

  URL="URL",

  STREET="LOCATION",
  STATE="LOCATION" , 
  CITY="LOCATION" , 
  COUNTY="LOCATION",
  SECONDARYADDRESS="LOCATION" ,
  STREETADDRESS = "LOCATION",
  STREET_ADDRESS ="LOCATION",
  FACILITY="LOCATION",
  LOC= "LOCATION",
  GPE="LOCATION",

  LOCATION = "LOCATION",

  PHONEIMEI="PHONE_NUMBER",
  PHONENUMBER="PHONE_NUMBER",
  PHONE="PHONE_NUMBER",
  PHONE_NUMBER = "PHONE_NUMBER",

  IPV4="IP_ADDRESS",
  IPV6="IP_ADDRESS",
  IP="IP_ADDRESS",
  IP_ADDRESS = "IP_ADDRESS",

  CREDITCARDNUMBER="CREDIT_CARD",
  CREDIT_CARD = "CREDIT_CARD",

  ZIPCODE="ZIP_CODE",
  ZIP_CODE ="ZIP_CODE",

  COMPANYNAME="ORGANIZATION",
  HOSP="ORGANIZATION",
  PATORG="ORGANIZATION",
  HOSPITAL="ORGANIZATION",
  ORG="ORGANIZATION",
  ORGANIZATION= "ORGANIZATION",

  IBAN="IBAN_CODE",
  IBAN_CODE = "IBAN_CODE",

  SSN="US_SSN",
  US_SSN = "US_SSN",

  AGE="AGE",

  NORP="NRP",

  ID="ID",

  

  


  AMOUNT="O",
  USERNAME="O",
  JOBTITLE="O",
  JOBAREA="O",
  ACCOUNTNAME="O",
  ACCOUNTNUMBER="O",
  JOBTYPE="O",
  BUILDINGNUMBER="O" ,
  CURRENCYSYMBOL="O" ,
  PASSWORD="O",
  SEX="O",
  GENDER="O",
  BITCOINADDRESS="O",
  MASKEDNUMBER="O",
  USERAGENT="O",
  CURRENCY="O",
  ETHEREUMADDRESS="O",
  NEARBYGPSCOORDINATE="O",
  CREDITCARDISSUER="O",
  ORDINALDIRECTION="O",
  MAC="O" ,
  VEHICLEVRM="O",
  EYECOLOR="O",
  CREDITCARDCVV="O",
  HEIGHT="O" ,
  LITECOINADDRESS="O",
  VEHICLEVIN="O" ,
  CURRENCYCODE="O",
  CURRENCYNAME="O" ,
  BIC="O",
  PIN="O",
  O= "O",

)



entities_mapping = presidio_entities_map

# %%
from presidio_evaluator.models import transformers_model
#  Set up the experiment tracker to log the experiment for reproducibility
experiment = get_experiment_tracker()
 
model = transformers_model.transformers_model(entity_mapping=entities_mapping,model_name="lakshyakh93/deberta_finetuned_pii")
# Create the evaluator object
evaluator = Evaluator(model=model)


# Track model and dataset params
params = {"dataset_name": dataset_name, "model_name": model.name}
params.update(model.to_log())
experiment.log_parameters(params)
experiment.log_dataset_hash(dataset)
#experiment.log_parameter("entity_mappings", json.dumps(entities_mapping))

# %%
## Run experiment

evaluation_results = evaluator.evaluate_all(dataset)
results = evaluator.calculate_score(evaluation_results)

# Track experiment results
experiment.log_metrics(results.to_log())
entities, confmatrix = results.to_confusion_matrix()
experiment.log_confusion_matrix(matrix=confmatrix, 
                                labels=entities)

# Plot output
plotter = evaluator.Plotter(model=model, 
                            results=results, 
                            output_folder = ".", 
                            model_name = model.name, 
                            beta = 2)


# end experiment
experiment.end()
# Out:
# Mapping entity values using this dictionary: {'FIRSTNAME': 'PERSON', 'LASTNAME': 'PERSON', 'MIDDLENAME': 'PERSON', 'FULLNAME': 'PERSON', 'PATIENT': 'PERSON', 'STAFF': 'PERSON', 'PER': 'PERSON', 'HCW': 'PERSON', 'PERSON': 'PERSON', 'DATE': 'DATE_TIME', 'TIME': 'DATE_TIME', 'DOB': 'DATE_TIME', 'DATE_TIME': 'DATE_TIME', 'EMAIL': 'EMAIL_ADDRESS', 'EMAIL_ADDRESS': 'EMAIL_ADDRESS', 'PREFIX': 'TITLE', 'TITLE': 'TITLE', 'URL': 'URL', 'STREET': 'LOCATION', 'STATE': 'LOCATION', 'CITY': 'LOCATION', 'COUNTY': 'LOCATION', 'SECONDARYADDRESS': 'LOCATION', 'STREETADDRESS': 'LOCATION', 'STREET_ADDRESS': 'LOCATION', 'FACILITY': 'LOCATION', 'LOC': 'LOCATION', 'GPE': 'LOCATION', 'LOCATION': 'LOCATION', 'PHONEIMEI': 'PHONE_NUMBER', 'PHONENUMBER': 'PHONE_NUMBER', 'PHONE': 'PHONE_NUMBER', 'PHONE_NUMBER': 'PHONE_NUMBER', 'IPV4': 'IP_ADDRESS', 'IPV6': 'IP_ADDRESS', 'IP': 'IP_ADDRESS', 'IP_ADDRESS': 'IP_ADDRESS', 'CREDITCARDNUMBER': 'CREDIT_CARD', 'CREDIT_CARD': 'CREDIT_CARD', 'ZIPCODE': 'ZIP_CODE', 'ZIP_CODE': 'ZIP_CODE', 'COMPANYNAME': 'ORGANIZATION', 'HOSP': 'ORGANIZATION', 'PATORG': 'ORGANIZATION', 'HOSPITAL': 'ORGANIZATION', 'ORG': 'ORGANIZATION', 'ORGANIZATION': 'ORGANIZATION', 'IBAN': 'IBAN_CODE', 'IBAN_CODE': 'IBAN_CODE', 'SSN': 'US_SSN', 'US_SSN': 'US_SSN', 'AGE': 'AGE', 'NORP': 'NRP', 'ID': 'ID', 'AMOUNT': 'O', 'USERNAME': 'O', 'JOBTITLE': 'O', 'JOBAREA': 'O', 'ACCOUNTNAME': 'O', 'ACCOUNTNUMBER': 'O', 'JOBTYPE': 'O', 'BUILDINGNUMBER': 'O', 'CURRENCYSYMBOL': 'O', 'PASSWORD': 'O', 'SEX': 'O', 'GENDER': 'O', 'BITCOINADDRESS': 'O', 'MASKEDNUMBER': 'O', 'USERAGENT': 'O', 'CURRENCY': 'O', 'ETHEREUMADDRESS': 'O', 'NEARBYGPSCOORDINATE': 'O', 'CREDITCARDISSUER': 'O', 'ORDINALDIRECTION': 'O', 'MAC': 'O', 'VEHICLEVRM': 'O', 'EYECOLOR': 'O', 'CREDITCARDCVV': 'O', 'HEIGHT': 'O', 'LITECOINADDRESS': 'O', 'VEHICLEVIN': 'O', 'CURRENCYCODE': 'O', 'CURRENCYNAME': 'O', 'BIC': 'O', 'PIN': 'O', 'O': 'O'}
# Running model transformers_model on dataset...
# Finished running model on dataset
# saving experiment data to experiment_20241119-222313.json

# %%
plotter.plot_scores()

# %%
errors = results.model_errors

# %%
ModelError.most_common_fp_tokens(errors)
# Out:
# Most common false positive tokens:
# [('...', 27),
#  ('Southern', 12),
#  ('mail', 10),
#  ('3', 9),
#  ('2', 9),
#  ('1', 9),
#  ('liftoff', 9),
#  ('Sir', 9),
#  ('bot', 9),
#  ('Phone', 9)]
# ---------------
# Example sentence with each FP token:
# 	- 3... 2... 1... liftoff! (`...` pred as NUMBER)
# 	- The Exversion Orchestra was founded in 1977. Since then, it has grown from a volunteer community orchestra to a fully professional orchestra serving Southern Tunisia (`Southern` pred as LOCATION)
# 	- Julieta S Almeida
#
# Staff development specialist
#
# Personal Info:
# Phone:
# 467 3395
#
# E-mail:
# JulietaSouzaAlmeida@cuvox.de
#
# Website:
# https://www.InvestmentInstructor.be/
#
# Address:
# 230 107 Igias Street Suite 503 Armenomonastiro Cyprus. (`mail` pred as PHONE_NUMBER)
# 	- 3... 2... 1... liftoff! (`3` pred as NUMBER)
# 	- 3... 2... 1... liftoff! (`2` pred as NUMBER)
# 	- 3... 2... 1... liftoff! (`1` pred as NUMBER)
# 	- 3... 2... 1... liftoff! (`liftoff` pred as NUMBER)
# 	- Excuse me, Sir bot, but I really don't like this tone (`Sir` pred as TITLE)
# 	- Excuse me, Sir bot, but I really don't like this tone (`bot` pred as PERSON)
# 	- Date: 1978-04-13 12:20:39
# Name: Toshimi Arata
# Phone: 0490 75 40 81 (`Phone` pred as PERSON)
# [('...', 27),
#  ('Southern', 12),
#  ('mail', 10),
#  ('3', 9),
#  ('2', 9),
#  ('1', 9),
#  ('liftoff', 9),
#  ('Sir', 9),
#  ('bot', 9),
#  ('Phone', 9)]

# %%
ModelError.most_common_fn_tokens(errors, n=50)
# Out:
# Most common false negative tokens:
# [('United', 11),
#  ('Greek', 9),
#  ('nan', 8),
#  ('DPO', 8),
#  ('Kingdom', 7),
#  ('AP', 7),
#  ('Cyprus', 7),
#  ('States', 7),
#  ('France', 7),
#  ('33', 7),
#  ('Sweden', 7),
#  ('Canada', 6),
#  ('Norway', 6),
#  ('American', 6),
#  ('Republic', 5),
#  ('46', 5),
#  ('53', 5),
#  ('Corporation', 4),
#  ('Estonia', 4),
#  ('Austria', 4),
#  ('Finland', 4),
#  ('Tuesday', 4),
#  ('ΠΑΦΟΣ', 4),
#  ('2004', 4),
#  ('21', 4),
#  ('78', 4),
#  ('Technologies', 4),
#  ('32', 4),
#  ('Greenlander', 4),
#  ('Germany', 4),
#  ('Russian', 4),
#  ('61', 4),
#  ('Data', 4),
#  ('80', 4),
#  ('LLC', 4),
#  ('65', 4),
#  ('64', 4),
#  ('AE', 4),
#  ('Czech', 4),
#  ('Research', 4),
#  ('Thursday', 4),
#  ('Consulting', 4),
#  ('1977', 3),
#  ('79', 3),
#  ('74', 3),
#  ('60', 3),
#  ('85', 3),
#  ('1971', 3),
#  ('63', 3),
#  ('Matthew', 3)]
# ---------------
# Example sentence with each FN token:
# 	- card number 347415977307943 is lost, can you please send a new one to 14 Crown Street Kishiev Squares
#  Suite 321
#  LONDON
#  United Kingdom 75419? I am in Sutri for a business trip (`United` annotated as LOCATION)
# 	- The address of Evidera is 928 Λ. Αλεξάνδρας 14
#  Suite 112
#  ΧΑΝ∆ΡΙΑ
#  Cyprus (Greek) 51034 (`Greek` annotated as LOCATION)
# 	- Billing address: Sophie Lang
#     3482 Via Franscini 71 Suite 838
#    Tujetsch
#     nan
#     7188 (`nan` annotated as LOCATION)
# 	- Bot: Where would you like this to be sent to? User: Unit 0822 Box 8858
# DPO AA 13319 (`DPO` annotated as LOCATION)
# 	- card number 347415977307943 is lost, can you please send a new one to 14 Crown Street Kishiev Squares
#  Suite 321
#  LONDON
#  United Kingdom 75419? I am in Sutri for a business trip (`Kingdom` annotated as LOCATION)
# 	- Hello I moved, please update my new address is PSC 6293, Box 8158
# APO AP 04336 (`AP` annotated as LOCATION)
# 	- The address of Evidera is 928 Λ. Αλεξάνδρας 14
#  Suite 112
#  ΧΑΝ∆ΡΙΑ
#  Cyprus (Greek) 51034 (`Cyprus` annotated as LOCATION)
# 	- Hello I moved, please update my new address is 224 4966 Bond Street
#  Suite 413
#  Warwick
#  United States (`States` annotated as LOCATION)
# 	- I will be travelling to France next week, so I need my passport to be ready by then (`France` annotated as LOCATION)
# 	- The letter arrived at 760 Passauer Strasse 33, Cite Guedouala, Tunisia last night. (`33` annotated as LOCATION)
# 	- 08615 Luddingsbo Mekanikusv 11
#  Suite 041
#  SPÅNGA
#  Sweden 65062 (`Sweden` annotated as LOCATION)
# 	- I will be travelling to Canada next week, so I need my passport to be ready by then (`Canada` annotated as LOCATION)
# 	- Blink-182 pay tribute here to the Norway. Producer Liviana Palerma explained to Fuse TV: "We all liked the idea of writing a song about our state, where we live and love. To me it's the most beautiful place in the world, this song was us giving credit to how lucky we are to have lived here and grown up here, raising families here, the whole thing." (`Norway` annotated as LOCATION)
# 	- The American Border Force have detained top-flight tennis player Erin Nyberg over visa disputes. (`American` annotated as NRP)
# 	- Who's coming to Czech Republic with me? (`Republic` annotated as LOCATION)
# 	- He just turned 46 years old (`46` annotated as AGE)
# 	- Rand Corporation
#
# 213 Pilekrogen 53 Apt. 263, Grand-Leez, Belgium 18431 (`53` annotated as LOCATION)
# 	- Microbilt Corporation is the brainchild of our 3 founders: Kónya, Becker and Vasquez.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea. (`Corporation` annotated as ORGANIZATION)
# 	- Estonia was super fun to visit! (`Estonia` annotated as LOCATION)
# 	- Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173. (`Austria` annotated as LOCATION)
# 	- Blink-182 pay tribute here to the Finland. Producer James Sparks explained to Fuse TV: "We all liked the idea of writing a song about our state, where we live and love. To me it's the most beautiful place in the world, this song was us giving credit to how lucky we are to have lived here and grown up here, raising families here, the whole thing." (`Finland` annotated as LOCATION)
# 	- Mr. Leiva flew to LEPPEN on Tuesday morning. (`Tuesday` annotated as DATE_TIME)
# 	- Tilly Nicholson lives at 10252 Μεγάλη Άμμος 184, ΠΑΦΟΣ (`ΠΑΦΟΣ` annotated as LOCATION)
# 	- Title VII of the Civil Rights Act of 2004 protects individuals against employment discrimination on the basis of race and color as well as national origin, sex, or religion. (`2004` annotated as DATE_TIME)
# 	- I need to add my addresses, here they are: 370 3911 Fourth Avenue Suite 697 Apt. 397, Mora de Rubielos, Spain 16200, and the corner of Postbox 21 and Elisabeth Parks (`21` annotated as LOCATION)
# 	- He just turned 78 years old (`78` annotated as AGE)
# 	- "The big three" of The Big Three Killed My Baby are the car manufacturers that dominate the economy of the White Stripes' home city Villafranca del Cid: White, Willis and Hoffman, Lucid and Loveland Technologies. "Don't feed me planned obsolescence," says Liisa Lepistö in an uncharacteristically political song, lamenting the demise of the unions in the 60s. (`Technologies` annotated as ORGANIZATION)
# 	- Mrs. Barbara Yudina Apt. 675 62314 Mellemvej 32
# Aalborg NO 9100 (`32` annotated as LOCATION)
# 	- Marisa Bisliev
#
# 583 Magrethevej 298
#  Apt. 123
#  Qasigiannguit
#  Greenlander 07609 (`Greenlander` annotated as LOCATION)
# 	- Who's coming to Germany with me? (`Germany` annotated as LOCATION)
# 	- So where are we meeting? There's this nice new Russian place downtown. Cool, what's the address? Oh do they serve vegan stuff? It's in 0269 Stensås terrasse 38
#  Suite 621
#  ARENDAL
#  Norway (`Russian` annotated as NRP)
# 	- Mr. Spears is a 61 year old man who grew up in Awenne. (`61` annotated as AGE)
# 	- >Gyala Antall
# >Google Public Data Explorer
# >Gyala Antall
# >3369 24 Clarke Avenue
# >Apt. 805
# >Pines Beach
# >New Zealand 34694 (`Data` annotated as ORGANIZATION)
# 	- I want to update my primary and secondary address to the same: 462 Stubengraben 80 Apt. 608
# Dusino San Michele, AT 31295 (`80` annotated as LOCATION)
# 	- Dzhambek is from Civic Impulse LLC (`LLC` annotated as ORGANIZATION)
# 	- I once lived in 416 Kiannonkatu 98 Apt. 934 OULU NO. I now live in 633 Strada Provinciale 65 22 Suite 455
# Gossau
# , nan
#  65662 (`65` annotated as LOCATION)
# 	- I want to update my primary and secondary address to the same: the corner of Pachergasse 64 and Radolič Harbor (`64` annotated as LOCATION)
# 	- I need to add my addresses, here they are: 638 2229 Wolmarans St
# Caxias do Sul, RS 24893, and USNV Botolen
# FPO AE 12382 (`AE` annotated as LOCATION)
# 	- The Czech Border Force have detained top-flight tennis player Amy Jones over visa disputes. (`Czech` annotated as NRP)
# 	- Estately songwriter Michele Østrem employs corporate lingo in the first verse of her Forrester Research resignation Letter (`Research` annotated as ORGANIZATION)
# 	- Mr. Slepička flew to MÖNSTERÅS on Thursday morning. (`Thursday` annotated as DATE_TIME)
# 	- "The big three" of The Big Three Killed My Baby are the car manufacturers that dominate the economy of the White Stripes' home city Voorburg: Nera Economic Consulting, Blackrock and Greatschools. "Don't feed me planned obsolescence," says Clara R. Dickson in an uncharacteristically political song, lamenting the demise of the unions in the 60s. (`Consulting` annotated as ORGANIZATION)
# 	- The Exversion Orchestra was founded in 1977. Since then, it has grown from a volunteer community orchestra to a fully professional orchestra serving Southern Tunisia (`1977` annotated as DATE_TIME)
# 	- This 79 year old female complaining of stomach pain. (`79` annotated as AGE)
# 	- This 74 year old female complaining of stomach pain. (`74` annotated as AGE)
# 	- Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173. (`60` annotated as PHONE_NUMBER)
# 	- Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173. (`85` annotated as PHONE_NUMBER)
# 	- During 1971, Mayo-Walters invested heavily in new microprocessor designs fostering the rapid growth of the computer industry. (`1971` annotated as DATE_TIME)
# 	- Please update the billing address with 27534 Þorsteinsgata 63
# MOSS
# , nan
#  51971 for this card: 4119268469462942 (`63` annotated as LOCATION)
# 	- Halldór: What a wife.
# Matthew: Remember me, Kelly? When I killed your brother, I talked just like this!
# Melanie: You saved my life! How can I ever repay you? (`Matthew` annotated as PERSON)
# [('United', 11),
#  ('Greek', 9),
#  ('nan', 8),
#  ('DPO', 8),
#  ('Kingdom', 7),
#  ('AP', 7),
#  ('Cyprus', 7),
#  ('States', 7),
#  ('France', 7),
#  ('33', 7),
#  ('Sweden', 7),
#  ('Canada', 6),
#  ('Norway', 6),
#  ('American', 6),
#  ('Republic', 5),
#  ('46', 5),
#  ('53', 5),
#  ('Corporation', 4),
#  ('Estonia', 4),
#  ('Austria', 4),
#  ('Finland', 4),
#  ('Tuesday', 4),
#  ('ΠΑΦΟΣ', 4),
#  ('2004', 4),
#  ('21', 4),
#  ('78', 4),
#  ('Technologies', 4),
#  ('32', 4),
#  ('Greenlander', 4),
#  ('Germany', 4),
#  ('Russian', 4),
#  ('61', 4),
#  ('Data', 4),
#  ('80', 4),
#  ('LLC', 4),
#  ('65', 4),
#  ('64', 4),
#  ('AE', 4),
#  ('Czech', 4),
#  ('Research', 4),
#  ('Thursday', 4),
#  ('Consulting', 4),
#  ('1977', 3),
#  ('79', 3),
#  ('74', 3),
#  ('60', 3),
#  ('85', 3),
#  ('1971', 3),
#  ('63', 3),
#  ('Matthew', 3)]

# %%
print("All errors:\n")
[print(error, "\n") for error in errors]
# Out:
# All errors:
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = PERSON, Token = Persint, Full text = The address of Persint is 6750 Koskikatu 25 Apt. 864
# Artilleros
# , CO
#  Uruguay 64677, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = CO, Full text = The address of Persint is 6750 Koskikatu 25 Apt. 864
# Artilleros
# , CO
#  Uruguay 64677, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 64677, Full text = The address of Persint is 6750 Koskikatu 25 Apt. 864
# Artilleros
# , CO
#  Uruguay 64677, Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Exversion, Full text = The Exversion Orchestra was founded in 1977. Since then, it has grown from a volunteer community orchestra to a fully professional orchestra serving Southern Tunisia, Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = 1977, Full text = The Exversion Orchestra was founded in 1977. Since then, it has grown from a volunteer community orchestra to a fully professional orchestra serving Southern Tunisia, Metadata = None
#
# type: FP, Annotation = O, prediction = LOCATION, Token = Southern, Full text = The Exversion Orchestra was founded in 1977. Since then, it has grown from a volunteer community orchestra to a fully professional orchestra serving Southern Tunisia, Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 4454794511390933, Full text = What is the limit for card 4454794511390933?, Metadata = None
#
# type: FP, Annotation = O, prediction = NAME, Token = Hobbits, Full text = When they weren't singing about Hobbits, satanic felines and interstellar journeys, they were singing about the verses from Faina D. Yefremova's Cautionary Tales. Is there a better example of unbridled creativity than early Yefremova?, Metadata = None
#
# type: FP, Annotation = O, prediction = NAME, Token = satanic, Full text = When they weren't singing about Hobbits, satanic felines and interstellar journeys, they were singing about the verses from Faina D. Yefremova's Cautionary Tales. Is there a better example of unbridled creativity than early Yefremova?, Metadata = None
#
# type: FP, Annotation = O, prediction = NAME, Token = felines, Full text = When they weren't singing about Hobbits, satanic felines and interstellar journeys, they were singing about the verses from Faina D. Yefremova's Cautionary Tales. Is there a better example of unbridled creativity than early Yefremova?, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Yefremova, Full text = When they weren't singing about Hobbits, satanic felines and interstellar journeys, they were singing about the verses from Faina D. Yefremova's Cautionary Tales. Is there a better example of unbridled creativity than early Yefremova?, Metadata = None
#
# type: FN, Annotation = US_SSN, prediction = O, Token = 460, Full text = Here's my SSN: 460-89-9847, Metadata = None
#
# type: FN, Annotation = US_SSN, prediction = O, Token = 89, Full text = Here's my SSN: 460-89-9847, Metadata = None
#
# type: FN, Annotation = US_SSN, prediction = O, Token = 9847, Full text = Here's my SSN: 460-89-9847, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Christiansen, Full text = Unlike the Christiansen novel, it's not about necrophilia. What it is about, I suppose is anyone's guess. A brilliant piece of baroque pop., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Canada, Full text = I will be travelling to Canada next week, so I need my passport to be ready by then, Metadata = None
#
# type: Wrong entity, Annotation = US_DRIVER_LICENSE, prediction = US_SSN, Token = 2270, Full text = my driver's license number is 2270-66-1551, Metadata = None
#
# type: Wrong entity, Annotation = US_DRIVER_LICENSE, prediction = US_SSN, Token = 66, Full text = my driver's license number is 2270-66-1551, Metadata = None
#
# type: Wrong entity, Annotation = US_DRIVER_LICENSE, prediction = US_SSN, Token = 1551, Full text = my driver's license number is 2270-66-1551, Metadata = None
#
# type: FN, Annotation = AGE, prediction = O, Token = 79, Full text = This 79 year old female complaining of stomach pain., Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = IBAN_CODE, Token = 595, Full text = Billing address: Sara Schwarz
#     28245 Puruntie 82 Apt. 595
#    LAPPEENRANTA
#     SK
#     53650, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = IP_ADDRESS, Token = LAPPEENRANTA, Full text = Billing address: Sara Schwarz
#     28245 Puruntie 82 Apt. 595
#    LAPPEENRANTA
#     SK
#     53650, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = IP_ADDRESS, Token = SK, Full text = Billing address: Sara Schwarz
#     28245 Puruntie 82 Apt. 595
#    LAPPEENRANTA
#     SK
#     53650, Metadata = None
#
# type: FN, Annotation = ZIP_CODE, prediction = O, Token = 53650, Full text = Billing address: Sara Schwarz
#     28245 Puruntie 82 Apt. 595
#    LAPPEENRANTA
#     SK
#     53650, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Nicole, Full text = Ubul: What a wife.
# Nicole: Remember me, Mary? When I killed your brother, I talked just like this!
# John: You saved my life! How can I ever repay you?, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = John, Full text = Ubul: What a wife.
# Nicole: Remember me, Mary? When I killed your brother, I talked just like this!
# John: You saved my life! How can I ever repay you?, Metadata = None
#
# type: Wrong entity, Annotation = TITLE, prediction = PERSON, Token = Dr., Full text = My name appears incorrectly on credit card statement could you please correct it to Dr. Berta Szöllössy?, Metadata = None
#
# type: FP, Annotation = O, prediction = NUMBER, Token = 3, Full text = 3... 2... 1... liftoff!, Metadata = None
#
# type: FP, Annotation = O, prediction = NUMBER, Token = ..., Full text = 3... 2... 1... liftoff!, Metadata = None
#
# type: FP, Annotation = O, prediction = NUMBER, Token = 2, Full text = 3... 2... 1... liftoff!, Metadata = None
#
# type: FP, Annotation = O, prediction = NUMBER, Token = ..., Full text = 3... 2... 1... liftoff!, Metadata = None
#
# type: FP, Annotation = O, prediction = NUMBER, Token = 1, Full text = 3... 2... 1... liftoff!, Metadata = None
#
# type: FP, Annotation = O, prediction = NUMBER, Token = ..., Full text = 3... 2... 1... liftoff!, Metadata = None
#
# type: FP, Annotation = O, prediction = NUMBER, Token = liftoff, Full text = 3... 2... 1... liftoff!, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Jensen, Full text = Unlike the Jensen novel, it's not about necrophilia. What it is about, I suppose is anyone's guess. A brilliant piece of baroque pop., Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = PERSON, Token = 20789, Full text = William Hughes
#
# 20789 Allika 46
#  Suite 501
#  Riisa
#
#  Estonia 62488, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Riisa, Full text = William Hughes
#
# 20789 Allika 46
#  Suite 501
#  Riisa
#
#  Estonia 62488, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 62488, Full text = William Hughes
#
# 20789 Allika 46
#  Suite 501
#  Riisa
#
#  Estonia 62488, Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Microbilt, Full text = Microbilt Corporation is the brainchild of our 3 founders: Kónya, Becker and Vasquez.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Corporation, Full text = Microbilt Corporation is the brainchild of our 3 founders: Kónya, Becker and Vasquez.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Kónya, Full text = Microbilt Corporation is the brainchild of our 3 founders: Kónya, Becker and Vasquez.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Becker, Full text = Microbilt Corporation is the brainchild of our 3 founders: Kónya, Becker and Vasquez.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Vasquez, Full text = Microbilt Corporation is the brainchild of our 3 founders: Kónya, Becker and Vasquez.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 1634, Full text = Tomomi Nishiyama lives at 86036 Rua do Arenque 1634, Goiânia, Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = PERSON, Token = Verdafero, Full text = Verdafero is the brainchild of our 3 founders: Eklund, Michael and Hodge.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Eklund, Full text = Verdafero is the brainchild of our 3 founders: Eklund, Michael and Hodge.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Michael, Full text = Verdafero is the brainchild of our 3 founders: Eklund, Michael and Hodge.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Hodge, Full text = Verdafero is the brainchild of our 3 founders: Eklund, Michael and Hodge.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Propublica, Full text = The Propublica office is at Růžena and Király u. 15., Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 4007070753690781, Full text = Could you please send me the last billed amount for cc 4007070753690781 on my e-mail UtaKortig@jourrapide.com?, Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = PERSON, Token = Avalara, Full text = The Avalara office is at PSC 0413, Box 8144
# APO AA 42323, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 42323, Full text = The Avalara office is at PSC 0413, Box 8144
# APO AA 42323, Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 905, Full text = I have done an online order but didn't get any message on my registered 905-674-3793. Could you please look into it ?, Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 674, Full text = I have done an online order but didn't get any message on my registered 905-674-3793. Could you please look into it ?, Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 3793, Full text = I have done an online order but didn't get any message on my registered 905-674-3793. Could you please look into it ?, Metadata = None
#
# type: FN, Annotation = AGE, prediction = O, Token = 74, Full text = This 74 year old female complaining of stomach pain., Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 630427373398, Full text = card number 630427373398 is lost, can you please send a new one to 1987 74 Diakou Street
#  Suite 680
#  Kissousa
#  Cyprus 36903? I am in ΛΕΥΚΩΣΙΑ for a business trip, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 1987, Full text = card number 630427373398 is lost, can you please send a new one to 1987 74 Diakou Street
#  Suite 680
#  Kissousa
#  Cyprus 36903? I am in ΛΕΥΚΩΣΙΑ for a business trip, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 36903, Full text = card number 630427373398 is lost, can you please send a new one to 1987 74 Diakou Street
#  Suite 680
#  Kissousa
#  Cyprus 36903? I am in ΛΕΥΚΩΣΙΑ for a business trip, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = ΛΕΥΚΩΣΙΑ, Full text = card number 630427373398 is lost, can you please send a new one to 1987 74 Diakou Street
#  Suite 680
#  Kissousa
#  Cyprus 36903? I am in ΛΕΥΚΩΣΙΑ for a business trip, Metadata = None
#
# type: FP, Annotation = O, prediction = LOCATION, Token = Club, Full text = When: 2000-04-16 11:34:35
# Where: UPTON SCUDAMORE Country Club., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = ΕΓΚΩΜΗ, Full text = I'm Naomi Ryan, originally from ΕΓΚΩΜΗ, and i'm 31 y/o., Metadata = None
#
# type: Wrong entity, Annotation = AGE, prediction = DATE_TIME, Token = 31, Full text = I'm Naomi Ryan, originally from ΕΓΚΩΜΗ, and i'm 31 y/o., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Canada, Full text = It may be too that Kaczmarek was influenced by an earlier song, "Carry Me Back To Canada," which was arranged and sung by Bonifacy Kaczmarek in 1977 (though Meza's song was actually about a boat!)., Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = 1977, Full text = It may be too that Kaczmarek was influenced by an earlier song, "Carry Me Back To Canada," which was arranged and sung by Bonifacy Kaczmarek in 1977 (though Meza's song was actually about a boat!)., Metadata = None
#
# type: FP, Annotation = O, prediction = PERSON, Token = C'm, Full text = C'mon, sing it with me: "You picked a fine time to leave me Mette, four hungry children and a crop in the field...", Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Mette, Full text = C'mon, sing it with me: "You picked a fine time to leave me Mette, four hungry children and a crop in the field...", Metadata = None
#
# type: FP, Annotation = O, prediction = NAME, Token = hungry, Full text = C'mon, sing it with me: "You picked a fine time to leave me Mette, four hungry children and a crop in the field...", Metadata = None
#
# type: FP, Annotation = O, prediction = NAME, Token = children, Full text = C'mon, sing it with me: "You picked a fine time to leave me Mette, four hungry children and a crop in the field...", Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 6586108984332171, Full text = My credit card 6586108984332171 has been lost, Can I request you to block it., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Estonia, Full text = Estonia was super fun to visit!, Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = SUFFIX, Token = M., Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: Wrong entity, Annotation = TITLE, prediction = PERSON, Token = Network, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = TITLE, prediction = O, Token = computer, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = TITLE, prediction = O, Token = systems, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = TITLE, prediction = O, Token = administrator, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 60, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 56, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 85, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 91, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = EMAIL_ADDRESS, prediction = O, Token = SzaszJanka@cuvox.de, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = URL, prediction = O, Token = https://www.UEarly.se/, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Brucker, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = FÜRLING, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Austria, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 25173, Full text = Janka M. Szász
#
# Network and computer systems administrator
#
# Personal Info:
# Phone:
# 60-56-85-91
#
# E-mail:
# SzaszJanka@cuvox.de
#
# Website:
# https://www.UEarly.se/
#
# Address:
# Brucker Bundesstrasse 31 Zezig Streets
#  Suite 245
#  FÜRLING
#  Austria 25173., Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 347415977307943, Full text = card number 347415977307943 is lost, can you please send a new one to 14 Crown Street Kishiev Squares
#  Suite 321
#  LONDON
#  United Kingdom 75419? I am in Sutri for a business trip, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = LONDON, Full text = card number 347415977307943 is lost, can you please send a new one to 14 Crown Street Kishiev Squares
#  Suite 321
#  LONDON
#  United Kingdom 75419? I am in Sutri for a business trip, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = United, Full text = card number 347415977307943 is lost, can you please send a new one to 14 Crown Street Kishiev Squares
#  Suite 321
#  LONDON
#  United Kingdom 75419? I am in Sutri for a business trip, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Kingdom, Full text = card number 347415977307943 is lost, can you please send a new one to 14 Crown Street Kishiev Squares
#  Suite 321
#  LONDON
#  United Kingdom 75419? I am in Sutri for a business trip, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 75419, Full text = card number 347415977307943 is lost, can you please send a new one to 14 Crown Street Kishiev Squares
#  Suite 321
#  LONDON
#  United Kingdom 75419? I am in Sutri for a business trip, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Tujetsch, Full text = Billing address: Sophie Lang
#     3482 Via Franscini 71 Suite 838
#    Tujetsch
#     nan
#     7188, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = nan, Full text = Billing address: Sophie Lang
#     3482 Via Franscini 71 Suite 838
#    Tujetsch
#     nan
#     7188, Metadata = None
#
# type: FN, Annotation = ZIP_CODE, prediction = O, Token = 7188, Full text = Billing address: Sophie Lang
#     3482 Via Franscini 71 Suite 838
#    Tujetsch
#     nan
#     7188, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = AP, Full text = Hello I moved, please update my new address is PSC 6293, Box 8158
# APO AP 04336, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 04336, Full text = Hello I moved, please update my new address is PSC 6293, Box 8158
# APO AP 04336, Metadata = None
#
# type: FP, Annotation = O, prediction = TITLE, Token = Sir, Full text = Excuse me, Sir bot, but I really don't like this tone, Metadata = None
#
# type: FP, Annotation = O, prediction = PERSON, Token = bot, Full text = Excuse me, Sir bot, but I really don't like this tone, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Jonas, Full text = A great song made even greater by a mandolin coda (not by Jonas Nielsen)., Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Nielsen, Full text = A great song made even greater by a mandolin coda (not by Jonas Nielsen)., Metadata = None
#
# type: FN, Annotation = TITLE, prediction = O, Token = Packager, Full text = Marie Langrová, the Packager, said: "I'm glad to hear that this has been withdrawn ג€“ quite why they thought this would go down well is beyond me.", Metadata = None
#
# type: FN, Annotation = US_SSN, prediction = O, Token = 514, Full text = Here's my SSN: 514-69-0360, Metadata = None
#
# type: FN, Annotation = US_SSN, prediction = O, Token = 69, Full text = Here's my SSN: 514-69-0360, Metadata = None
#
# type: FN, Annotation = US_SSN, prediction = O, Token = 0360, Full text = Here's my SSN: 514-69-0360, Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = 1971, Full text = During 1971, Mayo-Walters invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = NAME, Token = Mayo, Full text = During 1971, Mayo-Walters invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = NAME, Token = Walters, Full text = During 1971, Mayo-Walters invested heavily in new microprocessor designs fostering the rapid growth of the computer industry., Metadata = None
#
# type: FN, Annotation = AGE, prediction = O, Token = 60, Full text = My brother just turned 60, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Finland, Full text = Blink-182 pay tribute here to the Finland. Producer James Sparks explained to Fuse TV: "We all liked the idea of writing a song about our state, where we live and love. To me it's the most beautiful place in the world, this song was us giving credit to how lucky we are to have lived here and grown up here, raising families here, the whole thing.", Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Natalie, Full text = James Talbot listed his top 20 songs for Entertainment Weekly and had the balls to list this song at #15. (What did he put at #1 you ask? Answer:"Tube Snake Boogie" by Natalie Åberg ג€“ go figure), Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Gaetane, Full text = They had 6: Gaetane, Hannah, Anthony, Derek, Anna and Andrew., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Hannah, Full text = They had 6: Gaetane, Hannah, Anthony, Derek, Anna and Andrew., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Anthony, Full text = They had 6: Gaetane, Hannah, Anthony, Derek, Anna and Andrew., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Derek, Full text = They had 6: Gaetane, Hannah, Anthony, Derek, Anna and Andrew., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Anna, Full text = They had 6: Gaetane, Hannah, Anthony, Derek, Anna and Andrew., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Andrew, Full text = They had 6: Gaetane, Hannah, Anthony, Derek, Anna and Andrew., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = COMPANY_NAME, Token = Davis, Full text = The Davis, Reynolds and Williamson Orchestra was founded in 1977. Since then, it has grown from a volunteer community orchestra to a fully professional orchestra serving Southern Italy, Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = COMPANY_NAME, Token = Reynolds, Full text = The Davis, Reynolds and Williamson Orchestra was founded in 1977. Since then, it has grown from a volunteer community orchestra to a fully professional orchestra serving Southern Italy, Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = COMPANY_NAME, Token = Williamson, Full text = The Davis, Reynolds and Williamson Orchestra was founded in 1977. Since then, it has grown from a volunteer community orchestra to a fully professional orchestra serving Southern Italy, Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = 1977, Full text = The Davis, Reynolds and Williamson Orchestra was founded in 1977. Since then, it has grown from a volunteer community orchestra to a fully professional orchestra serving Southern Italy, Metadata = None
#
# type: FP, Annotation = O, prediction = LOCATION, Token = Southern, Full text = The Davis, Reynolds and Williamson Orchestra was founded in 1977. Since then, it has grown from a volunteer community orchestra to a fully professional orchestra serving Southern Italy, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = PERSON, Token = 233, Full text = Gregory Kudryashov
#
# 233 Erzsébet tér 19.
#  Suite 282
#  Domoszló
#  Hungary 34796
# (37) 788-063-Office\,07700 063 966-Fax, Metadata = None
#
# type: FP, Annotation = O, prediction = NUMBER, Token = Office\,07700, Full text = Gregory Kudryashov
#
# 233 Erzsébet tér 19.
#  Suite 282
#  Domoszló
#  Hungary 34796
# (37) 788-063-Office\,07700 063 966-Fax, Metadata = None
#
# type: FP, Annotation = O, prediction = NUMBER, Token = Fax, Full text = Gregory Kudryashov
#
# 233 Erzsébet tér 19.
#  Suite 282
#  Domoszló
#  Hungary 34796
# (37) 788-063-Office\,07700 063 966-Fax, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 210, Full text = bot: where would you like this to be sent to? user: 0605 πεντέλης 210 apt. 999
# delmas, mp 35739, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = mp, Full text = bot: where would you like this to be sent to? user: 0605 πεντέλης 210 apt. 999
# delmas, mp 35739, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 35739, Full text = bot: where would you like this to be sent to? user: 0605 πεντέλης 210 apt. 999
# delmas, mp 35739, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Kevin, Full text = My great great grandfather was called Kevin Veitonen II, and my great great grandmother was called Brosca Erdôs, Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 541, Full text = I would like to stop receiving messages to 541-714-1388, Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 714, Full text = I would like to stop receiving messages to 541-714-1388, Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 1388, Full text = I would like to stop receiving messages to 541-714-1388, Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = Tuesday, Full text = Mr. Leiva flew to LEPPEN on Tuesday morning., Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 180016070420458, Full text = I have lost my card 180016070420458. Could you please block my credit card ASAP ? My name is Aantje Mourik., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 10252, Full text = Tilly Nicholson lives at 10252 Μεγάλη Άμμος 184, ΠΑΦΟΣ, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Άμμος, Full text = Tilly Nicholson lives at 10252 Μεγάλη Άμμος 184, ΠΑΦΟΣ, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 184, Full text = Tilly Nicholson lives at 10252 Μεγάλη Άμμος 184, ΠΑΦΟΣ, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = ΠΑΦΟΣ, Full text = Tilly Nicholson lives at 10252 Μεγάλη Άμμος 184, ΠΑΦΟΣ, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = cite, Full text = when: 2006-04-07 09:00:27
# where: cite ben hjel country club., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Collective, Full text = Collective Ip is the brainchild of our 3 founders: Monjeau, Graves and Reed.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Ip, Full text = Collective Ip is the brainchild of our 3 founders: Monjeau, Graves and Reed.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Monjeau, Full text = Collective Ip is the brainchild of our 3 founders: Monjeau, Graves and Reed.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Graves, Full text = Collective Ip is the brainchild of our 3 founders: Monjeau, Graves and Reed.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Reed, Full text = Collective Ip is the brainchild of our 3 founders: Monjeau, Graves and Reed.  The idea was born (on the beach) while they were constructing a website to be the basis of another start-up idea., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 63, Full text = Please update the billing address with 27534 Þorsteinsgata 63
# MOSS
# , nan
#  51971 for this card: 4119268469462942, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = MOSS, Full text = Please update the billing address with 27534 Þorsteinsgata 63
# MOSS
# , nan
#  51971 for this card: 4119268469462942, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = nan, Full text = Please update the billing address with 27534 Þorsteinsgata 63
# MOSS
# , nan
#  51971 for this card: 4119268469462942, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 51971, Full text = Please update the billing address with 27534 Þorsteinsgata 63
# MOSS
# , nan
#  51971 for this card: 4119268469462942, Metadata = None
#
# type: Wrong entity, Annotation = IBAN_CODE, prediction = CREDIT_CARD, Token = GB56HXDO88167774656119, Full text = Are there any charges applied for money transfer from GB56HXDO88167774656119 to other bank accounts, Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Aunt, Full text = I work for Aunt Bertha Inc, Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = NAME, Token = Bertha, Full text = I work for Aunt Bertha Inc, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Miami, Full text = I'm in Miami, at the conference, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Matthew, Full text = Halldór: What a wife.
# Matthew: Remember me, Kelly? When I killed your brother, I talked just like this!
# Melanie: You saved my life! How can I ever repay you?, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Melanie, Full text = Halldór: What a wife.
# Matthew: Remember me, Kelly? When I killed your brother, I talked just like this!
# Melanie: You saved my life! How can I ever repay you?, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 72, Full text = I'll meet you at 25615 Tawastintie 72 Apt. 004
# KNIVSTA, nan 18237 after the concert., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = nan, Full text = I'll meet you at 25615 Tawastintie 72 Apt. 004
# KNIVSTA, nan 18237 after the concert., Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 18237, Full text = I'll meet you at 25615 Tawastintie 72 Apt. 004
# KNIVSTA, nan 18237 after the concert., Metadata = None
#
# type: Wrong entity, Annotation = AGE, prediction = DATE_TIME, Token = 23, Full text = My birthday is on the weekend. I'll turn 23., Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 4969800024734372, Full text = Can I withdraw cash using my card 4969800024734372 at aTM center ?, Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = 2001, Full text = Title VII of the Civil Rights Act of 2001 protects individuals against employment discrimination on the basis of race and color as well as national origin, sex, or religion., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = LOCATION, Token = Hawkins, Full text = Tomomi is from Hawkins, Richardson and Santana, Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = LOCATION, Token = Richardson, Full text = Tomomi is from Hawkins, Richardson and Santana, Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = LOCATION, Token = Santana, Full text = Tomomi is from Hawkins, Richardson and Santana, Metadata = None
#
# type: FN, Annotation = AGE, prediction = O, Token = 19, Full text = Mr. Pálffy is a 19 year old man who grew up in SUND., Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 70942, Full text = Please return to Unit 4719 Box 7394
# DPO AP 70942 in case of an issue., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Capital, Full text = Hanne I. Kreutzmann from Can Capital is the keynote speaker, Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 30288610434735, Full text = Please charge my credit card. Number is 30288610434735, Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = 2004, Full text = Title VII of the Civil Rights Act of 2004 protects individuals against employment discrimination on the basis of race and color as well as national origin, sex, or religion., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = COMPANY_NAME, Token = Rivas, Full text = Alvir spent a year at Weeks-Rivas as the assistant to Alvir D. Pušaver, and the following year at Healthpocket Inc in SCHLAGLES, which later became Credit Karma in 1980., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = COMPANY_NAME, Token = Healthpocket, Full text = Alvir spent a year at Weeks-Rivas as the assistant to Alvir D. Pušaver, and the following year at Healthpocket Inc in SCHLAGLES, which later became Credit Karma in 1980., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Credit, Full text = Alvir spent a year at Weeks-Rivas as the assistant to Alvir D. Pušaver, and the following year at Healthpocket Inc in SCHLAGLES, which later became Credit Karma in 1980., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Karma, Full text = Alvir spent a year at Weeks-Rivas as the assistant to Alvir D. Pušaver, and the following year at Healthpocket Inc in SCHLAGLES, which later became Credit Karma in 1980., Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = 1980, Full text = Alvir spent a year at Weeks-Rivas as the assistant to Alvir D. Pušaver, and the following year at Healthpocket Inc in SCHLAGLES, which later became Credit Karma in 1980., Metadata = None
#
# type: FP, Annotation = O, prediction = PERSON, Token = Phone, Full text = Date: 1978-04-13 12:20:39
# Name: Toshimi Arata
# Phone: 0490 75 40 81, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 16200, Full text = I need to add my addresses, here they are: 370 3911 Fourth Avenue Suite 697 Apt. 397, Mora de Rubielos, Spain 16200, and the corner of Postbox 21 and Elisabeth Parks, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Postbox, Full text = I need to add my addresses, here they are: 370 3911 Fourth Avenue Suite 697 Apt. 397, Mora de Rubielos, Spain 16200, and the corner of Postbox 21 and Elisabeth Parks, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 21, Full text = I need to add my addresses, here they are: 370 3911 Fourth Avenue Suite 697 Apt. 397, Mora de Rubielos, Spain 16200, and the corner of Postbox 21 and Elisabeth Parks, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Elisabeth, Full text = I need to add my addresses, here they are: 370 3911 Fourth Avenue Suite 697 Apt. 397, Mora de Rubielos, Spain 16200, and the corner of Postbox 21 and Elisabeth Parks, Metadata = None
#
# type: FN, Annotation = AGE, prediction = O, Token = 21, Full text = Mr. Baader is a 21 year old man who grew up in Remniku., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 137, Full text = Pedestrians must enter on 137 Avenue Teboulbi St. the first three months, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Avenue, Full text = Pedestrians must enter on 137 Avenue Teboulbi St. the first three months, Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = PERSON, Token = Evidera, Full text = The address of Evidera is 928 Λ. Αλεξάνδρας 14
#  Suite 112
#  ΧΑΝ∆ΡΙΑ
#  Cyprus (Greek) 51034, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 14, Full text = The address of Evidera is 928 Λ. Αλεξάνδρας 14
#  Suite 112
#  ΧΑΝ∆ΡΙΑ
#  Cyprus (Greek) 51034, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = ΧΑΝ∆ΡΙΑ, Full text = The address of Evidera is 928 Λ. Αλεξάνδρας 14
#  Suite 112
#  ΧΑΝ∆ΡΙΑ
#  Cyprus (Greek) 51034, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Cyprus, Full text = The address of Evidera is 928 Λ. Αλεξάνδρας 14
#  Suite 112
#  ΧΑΝ∆ΡΙΑ
#  Cyprus (Greek) 51034, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Greek, Full text = The address of Evidera is 928 Λ. Αλεξάνδρας 14
#  Suite 112
#  ΧΑΝ∆ΡΙΑ
#  Cyprus (Greek) 51034, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 51034, Full text = The address of Evidera is 928 Λ. Αλεξάνδρας 14
#  Suite 112
#  ΧΑΝ∆ΡΙΑ
#  Cyprus (Greek) 51034, Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 2623322164608847, Full text = Need to change billing date of my card 2623322164608847, Metadata = None
#
# type: FN, Annotation = IP_ADDRESS, prediction = O, Token = //!%20\|106.31.73.20|%20/, Full text = Inject SELECT * FROM Users WHERE client_ip = ?%//!%20\|106.31.73.20|%20/, Metadata = None
#
# type: FP, Annotation = O, prediction = NAME, Token = lemurs, Full text = You will be responsible for the husbandry and care of a large variety of species including lemurs, antelope, camels, and more, Metadata = None
#
# type: FP, Annotation = O, prediction = NAME, Token = antelope, Full text = You will be responsible for the husbandry and care of a large variety of species including lemurs, antelope, camels, and more, Metadata = None
#
# type: FP, Annotation = O, prediction = NAME, Token = camels, Full text = You will be responsible for the husbandry and care of a large variety of species including lemurs, antelope, camels, and more, Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 213176828496175, Full text = Can I withdraw cash using my card 213176828496175 at aTM center ?, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = Jones, Full text = Ms. Jones flew to Bessastaðahreppur on Saturday morning., Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = Saturday, Full text = Ms. Jones flew to Bessastaðahreppur on Saturday morning., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Compliance, Full text = The address of Compliance And Risks is 9554 62 Rue Gafsa Apt. 981
# Toronto
# , ON
#  82269, Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Risks, Full text = The address of Compliance And Risks is 9554 62 Rue Gafsa Apt. 981
# Toronto
# , ON
#  82269, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 82269, Full text = The address of Compliance And Risks is 9554 62 Rue Gafsa Apt. 981
# Toronto
# , ON
#  82269, Metadata = None
#
# type: FN, Annotation = NRP, prediction = O, Token = English, Full text = From the film English graffiti (also features Kate M Begum. What's not to love?, Metadata = None
#
# type: FN, Annotation = AGE, prediction = O, Token = 69, Full text = He just turned 69 years old, Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = Monday, Full text = Mr. Pavlović flew to STAXROITH on Monday morning., Metadata = None
#
# type: FN, Annotation = AGE, prediction = O, Token = 78, Full text = He just turned 78 years old, Metadata = None
#
# type: FN, Annotation = DATE_TIME, prediction = O, Token = Saturday, Full text = Ms. Margarot flew to Loeches on Saturday morning., Metadata = None
#
# type: FP, Annotation = O, prediction = LOCATION, Token = Stripes, Full text = "The big three" of The Big Three Killed My Baby are the car manufacturers that dominate the economy of the White Stripes' home city Villafranca del Cid: White, Willis and Hoffman, Lucid and Loveland Technologies. "Don't feed me planned obsolescence," says Liisa Lepistö in an uncharacteristically political song, lamenting the demise of the unions in the 60s., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = COMPANY_NAME, Token = White, Full text = "The big three" of The Big Three Killed My Baby are the car manufacturers that dominate the economy of the White Stripes' home city Villafranca del Cid: White, Willis and Hoffman, Lucid and Loveland Technologies. "Don't feed me planned obsolescence," says Liisa Lepistö in an uncharacteristically political song, lamenting the demise of the unions in the 60s., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = COMPANY_NAME, Token = Willis, Full text = "The big three" of The Big Three Killed My Baby are the car manufacturers that dominate the economy of the White Stripes' home city Villafranca del Cid: White, Willis and Hoffman, Lucid and Loveland Technologies. "Don't feed me planned obsolescence," says Liisa Lepistö in an uncharacteristically political song, lamenting the demise of the unions in the 60s., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = COMPANY_NAME, Token = Hoffman, Full text = "The big three" of The Big Three Killed My Baby are the car manufacturers that dominate the economy of the White Stripes' home city Villafranca del Cid: White, Willis and Hoffman, Lucid and Loveland Technologies. "Don't feed me planned obsolescence," says Liisa Lepistö in an uncharacteristically political song, lamenting the demise of the unions in the 60s., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Lucid, Full text = "The big three" of The Big Three Killed My Baby are the car manufacturers that dominate the economy of the White Stripes' home city Villafranca del Cid: White, Willis and Hoffman, Lucid and Loveland Technologies. "Don't feed me planned obsolescence," says Liisa Lepistö in an uncharacteristically political song, lamenting the demise of the unions in the 60s., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Loveland, Full text = "The big three" of The Big Three Killed My Baby are the car manufacturers that dominate the economy of the White Stripes' home city Villafranca del Cid: White, Willis and Hoffman, Lucid and Loveland Technologies. "Don't feed me planned obsolescence," says Liisa Lepistö in an uncharacteristically political song, lamenting the demise of the unions in the 60s., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Technologies, Full text = "The big three" of The Big Three Killed My Baby are the car manufacturers that dominate the economy of the White Stripes' home city Villafranca del Cid: White, Willis and Hoffman, Lucid and Loveland Technologies. "Don't feed me planned obsolescence," says Liisa Lepistö in an uncharacteristically political song, lamenting the demise of the unions in the 60s., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Republic, Full text = Who's coming to Czech Republic with me?, Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Usamov, Full text = Is there a better crafted pop song on this list? Usamov and Bowers were precision engineers., Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = NAME, Token = Bowers, Full text = Is there a better crafted pop song on this list? Usamov and Bowers were precision engineers., Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = PERSON, Token = 4844, Full text = Stephan M Urner
#
# 4844 Søndergade 52
#  Apt. 656
#  Brønderslev
#
#  Denmark 35018, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 35018, Full text = Stephan M Urner
#
# 4844 Søndergade 52
#  Apt. 656
#  Brønderslev
#
#  Denmark 35018, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 99178, Full text = 28030 Edeby 55
#  Apt. 297
#  TYSTBERGA
# ...
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Microsoft, Full text = I used to work for Microsoft as Biomedical engineer, but quit a few months ago. Now I'm unemployed., Metadata = None
#
# type: FN, Annotation = TITLE, prediction = O, Token = Biomedical, Full text = I used to work for Microsoft as Biomedical engineer, but quit a few months ago. Now I'm unemployed., Metadata = None
#
# type: FN, Annotation = TITLE, prediction = O, Token = engineer, Full text = I used to work for Microsoft as Biomedical engineer, but quit a few months ago. Now I'm unemployed., Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Wolfram, Full text = Wolfram Research is an Hungarian multinational investment bank and financial services company, Metadata = None
#
# type: FN, Annotation = ORGANIZATION, prediction = O, Token = Research, Full text = Wolfram Research is an Hungarian multinational investment bank and financial services company, Metadata = None
#
# type: FN, Annotation = NRP, prediction = O, Token = Hungarian, Full text = Wolfram Research is an Hungarian multinational investment bank and financial services company, Metadata = None
#
# type: Wrong entity, Annotation = TITLE, prediction = PERSON, Token = Accountant, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: FP, Annotation = O, prediction = PERSON, Token = Personal, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: FN, Annotation = PHONE_NUMBER, prediction = O, Token = 51, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: FP, Annotation = O, prediction = PHONE_NUMBER, Token = E, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: FP, Annotation = O, prediction = PHONE_NUMBER, Token = mail, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: Wrong entity, Annotation = EMAIL_ADDRESS, prediction = PHONE_NUMBER, Token = LaylaGairbekov@rhyta.com, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: FP, Annotation = O, prediction = PHONE_NUMBER, Token = Website, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: Wrong entity, Annotation = URL, prediction = PHONE_NUMBER, Token = http://www.GoalForum.com.au/, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = PHONE_NUMBER, Token = 22120, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 78, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = ASKIM, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Sweden, Full text = Layla Gairbekov
#
# Accountant
#
# Personal Info:
# Phone:
# 51 516 33 75
#
# E-mail:
# LaylaGairbekov@rhyta.com
#
# Website:
# http://www.GoalForum.com.au/
#
# Address:
# 22120 Eriksbo Västergärde 78
#  Suite 721
#  ASKIM
#  Sweden., Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = PERSON, Token = 22829, Full text = Fausto Calabrese
#
# 22829 Jagerij 64
#  Apt. 591
#  Mazée
#  Belgium 65260, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 65260, Full text = Fausto Calabrese
#
# 22829 Jagerij 64
#  Apt. 591
#  Mazée
#  Belgium 65260, Metadata = None
#
# type: FN, Annotation = PERSON, prediction = O, Token = F., Full text = The Gunnhildur F. Helgadóttir version recorded for Arpin Van Lines became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = PERSON, Token = Arpin, Full text = The Gunnhildur F. Helgadóttir version recorded for Arpin Van Lines became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = PERSON, Token = Van, Full text = The Gunnhildur F. Helgadóttir version recorded for Arpin Van Lines became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = PERSON, Token = Lines, Full text = The Gunnhildur F. Helgadóttir version recorded for Arpin Van Lines became the first celebrity recording by a classical musician to sell one million copies. The song was awarded the seventh gold disc ever granted., Metadata = None
#
# type: FN, Annotation = TITLE, prediction = O, Token = Cinematographer, Full text = Kristíana R Valbergsdóttir, the Cinematographer, said: "I'm glad to hear that this has been withdrawn ג€“ quite why they thought this would go down well is beyond me.", Metadata = None
#
# type: FN, Annotation = CREDIT_CARD, prediction = O, Token = 4203895020367512, Full text = What is the limit for card 4203895020367512?, Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = TITLE, Token = Dr., Full text = My great great grandfather was called Yulan Peres, and my great great grandmother was called Dr. Jennifer Holst, Metadata = None
#
# type: Wrong entity, Annotation = ORGANIZATION, prediction = IP_ADDRESS, Token = Locavore, Full text = >
# > Benito Bianchi
# > Locavore
# > Benito Bianchi
# > 040 Snellmaninkatu 55
# > Apt. 022
# > ESPOO
# > Finland 23221, Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = IP_ADDRESS, Token = Benito, Full text = >
# > Benito Bianchi
# > Locavore
# > Benito Bianchi
# > 040 Snellmaninkatu 55
# > Apt. 022
# > ESPOO
# > Finland 23221, Metadata = None
#
# type: Wrong entity, Annotation = PERSON, prediction = IP_ADDRESS, Token = Bianchi, Full text = >
# > Benito Bianchi
# > Locavore
# > Benito Bianchi
# > 040 Snellmaninkatu 55
# > Apt. 022
# > ESPOO
# > Finland 23221, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = IP_ADDRESS, Token = 040, Full text = >
# > Benito Bianchi
# > Locavore
# > Benito Bianchi
# > 040 Snellmaninkatu 55
# > Apt. 022
# > ESPOO
# > Finland 23221, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = 55, Full text = >
# > Benito Bianchi
# > Locavore
# > Benito Bianchi
# > 040 Snellmaninkatu 55
# > Apt. 022
# > ESPOO
# > Finland 23221, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = ESPOO, Full text = >
# > Benito Bianchi
# > Locavore
# > Benito Bianchi
# > 040 Snellmaninkatu 55
# > Apt. 022
# > ESPOO
# > Finland 23221, Metadata = None
#
# type: FN, Annotation = LOCATION, prediction = O, Token = Finland, Full text = >
# > Benito Bianchi
# > Locavore
# > Benito Bianchi
# > 040 Snellmaninkatu 55
# > Apt. 022
# > ESPOO
# > Finland 23221, Metadata = None
#
# type: Wrong entity, Annotation = LOCATION, prediction = ZIP_CODE, Token = 23221, Full text = >
# > Benito Bianchi
# > Locavore
# > Benito Bianchi
# > 040 Snellmaninkatu 55
# > Apt. 022
# > ESPOO
# > Finland 23221, Metadata = None
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
plotter.plot_confusion_matrix(entities=entities, confmatrix=confmatrix)

# %%
errors = results.model_errors

# %%
fns_df = ModelError.get_fns_dataframe(errors, entity=["LOCATION"])
fns_df[["full_text", "token", "annotation", "prediction"]][:20]
# Out:
#                                                                                                                                                                                                                                                                                                                                                        full_text  \
# 0                                                                                                                                                                                                                                                                         The address of Persint is 6750 Koskikatu 25 Apt. 864\nArtilleros\n, CO\n Uruguay 64677
# 1                                                                                                                                                                                                                                                                            I will be travelling to Canada next week, so I need my passport to be ready by then
# 2                                                                                                                                                                                                                                                                                        William Hughes\n\n20789 Allika 46\n Suite 501\n Riisa\n\n Estonia 62488
# 3                                                                                                                                                                                                                                                                                                   Tomomi Nishiyama lives at 86036 Rua do Arenque 1634, Goiânia
# 4                                                                                                                                                                                                                                                                                                      The Avalara office is at PSC 0413, Box 8144\nAPO AA 42323
# 5                                                                                                                                                                                           card number 630427373398 is lost, can you please send a new one to 1987 74 Diakou Street\n Suite 680\n Kissousa\n Cyprus 36903? I am in ΛΕΥΚΩΣΙΑ for a business trip
# 6                                                                                                                                                                                           card number 630427373398 is lost, can you please send a new one to 1987 74 Diakou Street\n Suite 680\n Kissousa\n Cyprus 36903? I am in ΛΕΥΚΩΣΙΑ for a business trip
# 7                                                                                                                                                                                                                                                                                                        I'm Naomi Ryan, originally from ΕΓΚΩΜΗ, and i'm 31 y/o.
# 8                                                                                                                                                          It may be too that Kaczmarek was influenced by an earlier song, "Carry Me Back To Canada," which was arranged and sung by Bonifacy Kaczmarek in 1977 (though Meza's song was actually about a boat!).
# 9                                                                                                                                                                                                                                                                                                                                Estonia was super fun to visit!
# 10                                                                                            Janka M. Szász\n\nNetwork and computer systems administrator\n\nPersonal Info:\nPhone:\n60-56-85-91\n\nE-mail:\nSzaszJanka@cuvox.de\n\nWebsite:\nhttps://www.UEarly.se/\n\nAddress:\nBrucker Bundesstrasse 31 Zezig Streets\n Suite 245\n FÜRLING\n Austria 25173.
# 11                                                                                            Janka M. Szász\n\nNetwork and computer systems administrator\n\nPersonal Info:\nPhone:\n60-56-85-91\n\nE-mail:\nSzaszJanka@cuvox.de\n\nWebsite:\nhttps://www.UEarly.se/\n\nAddress:\nBrucker Bundesstrasse 31 Zezig Streets\n Suite 245\n FÜRLING\n Austria 25173.
# 12                                                                                            Janka M. Szász\n\nNetwork and computer systems administrator\n\nPersonal Info:\nPhone:\n60-56-85-91\n\nE-mail:\nSzaszJanka@cuvox.de\n\nWebsite:\nhttps://www.UEarly.se/\n\nAddress:\nBrucker Bundesstrasse 31 Zezig Streets\n Suite 245\n FÜRLING\n Austria 25173.
# 13                                                                                                                                                                          card number 347415977307943 is lost, can you please send a new one to 14 Crown Street Kishiev Squares\n Suite 321\n LONDON\n United Kingdom 75419? I am in Sutri for a business trip
# 14                                                                                                                                                                          card number 347415977307943 is lost, can you please send a new one to 14 Crown Street Kishiev Squares\n Suite 321\n LONDON\n United Kingdom 75419? I am in Sutri for a business trip
# 15                                                                                                                                                                          card number 347415977307943 is lost, can you please send a new one to 14 Crown Street Kishiev Squares\n Suite 321\n LONDON\n United Kingdom 75419? I am in Sutri for a business trip
# 16                                                                                                                                                                                                                                                             Billing address: Sophie Lang\n    3482 Via Franscini 71 Suite 838\n   Tujetsch\n    nan\n    7188
# 17                                                                                                                                                                                                                                                             Billing address: Sophie Lang\n    3482 Via Franscini 71 Suite 838\n   Tujetsch\n    nan\n    7188
# 18                                                                                                                                                                                                                                                                               Hello I moved, please update my new address is PSC 6293, Box 8158\nAPO AP 04336
# 19  Blink-182 pay tribute here to the Finland. Producer James Sparks explained to Fuse TV: "We all liked the idea of writing a song about our state, where we live and love. To me it's the most beautiful place in the world, this song was us giving credit to how lucky we are to have lived here and grown up here, raising families here, the whole thing."
#
#        token annotation prediction
# 0         CO   LOCATION          O
# 1     Canada   LOCATION          O
# 2      Riisa   LOCATION          O
# 3       1634   LOCATION          O
# 4      42323   LOCATION          O
# 5       1987   LOCATION          O
# 6   ΛΕΥΚΩΣΙΑ   LOCATION          O
# 7     ΕΓΚΩΜΗ   LOCATION          O
# 8     Canada   LOCATION          O
# 9    Estonia   LOCATION          O
# 10   Brucker   LOCATION          O
# 11   FÜRLING   LOCATION          O
# 12   Austria   LOCATION          O
# 13    LONDON   LOCATION          O
# 14    United   LOCATION          O
# 15   Kingdom   LOCATION          O
# 16  Tujetsch   LOCATION          O
# 17       nan   LOCATION          O
# 18        AP   LOCATION          O
# 19   Finland   LOCATION          O

# %%
from presidio_evaluator.models import transformers_model
#  Set up the experiment tracker to log the experiment for reproducibility
experiment = get_experiment_tracker()
 
model = transformers_model.transformers_model(entity_mapping=entities_mapping,model_name="lakshyakh93/deberta_finetuned_pii" , aggregation_strategy='max')
# Create the evaluator object
evaluator = Evaluator(model=model)


# Track model and dataset params
params = {"dataset_name": dataset_name, "model_name": model.name}
params.update(model.to_log())
experiment.log_parameters(params)
experiment.log_dataset_hash(dataset)
#experiment.log_parameter("entity_mappings", json.dumps(entities_mapping))
# Out:
# c:\Users\WIN10\AppData\Local\pypoetry\Cache\virtualenvs\presidio-evaluator-IFEnQHLa-py3.12\Lib\site-packages\huggingface_hub\file_download.py:1142: FutureWarning:
#
# `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#
# c:\Users\WIN10\AppData\Local\pypoetry\Cache\virtualenvs\presidio-evaluator-IFEnQHLa-py3.12\Lib\site-packages\transformers\modeling_utils.py:519: FutureWarning:
#
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %%
## Run experiment

evaluation_results = evaluator.evaluate_all(dataset)
results = evaluator.calculate_score(evaluation_results)

# Track experiment results
experiment.log_metrics(results.to_log())
entities, confmatrix = results.to_confusion_matrix()
experiment.log_confusion_matrix(matrix=confmatrix, 
                                labels=entities)

# Plot output
plotter = evaluator.Plotter(model=model, 
                            results=results, 
                            output_folder = ".", 
                            model_name = model.name, 
                            beta = 2)


# end experiment
experiment.end()
# Out:
# Mapping entity values using this dictionary: {'FIRSTNAME': 'PERSON', 'LASTNAME': 'PERSON', 'MIDDLENAME': 'PERSON', 'FULLNAME': 'PERSON', 'PATIENT': 'PERSON', 'STAFF': 'PERSON', 'PER': 'PERSON', 'HCW': 'PERSON', 'PERSON': 'PERSON', 'DATE': 'DATE_TIME', 'TIME': 'DATE_TIME', 'DOB': 'DATE_TIME', 'DATE_TIME': 'DATE_TIME', 'EMAIL': 'EMAIL_ADDRESS', 'EMAIL_ADDRESS': 'EMAIL_ADDRESS', 'PREFIX': 'TITLE', 'TITLE': 'TITLE', 'URL': 'URL', 'STREET': 'LOCATION', 'STATE': 'LOCATION', 'CITY': 'LOCATION', 'COUNTY': 'LOCATION', 'SECONDARYADDRESS': 'LOCATION', 'STREETADDRESS': 'LOCATION', 'STREET_ADDRESS': 'LOCATION', 'FACILITY': 'LOCATION', 'LOC': 'LOCATION', 'GPE': 'LOCATION', 'LOCATION': 'LOCATION', 'PHONEIMEI': 'PHONE_NUMBER', 'PHONENUMBER': 'PHONE_NUMBER', 'PHONE': 'PHONE_NUMBER', 'PHONE_NUMBER': 'PHONE_NUMBER', 'IPV4': 'IP_ADDRESS', 'IPV6': 'IP_ADDRESS', 'IP': 'IP_ADDRESS', 'IP_ADDRESS': 'IP_ADDRESS', 'CREDITCARDNUMBER': 'CREDIT_CARD', 'CREDIT_CARD': 'CREDIT_CARD', 'ZIPCODE': 'ZIP_CODE', 'ZIP_CODE': 'ZIP_CODE', 'COMPANYNAME': 'ORGANIZATION', 'HOSP': 'ORGANIZATION', 'PATORG': 'ORGANIZATION', 'HOSPITAL': 'ORGANIZATION', 'ORG': 'ORGANIZATION', 'ORGANIZATION': 'ORGANIZATION', 'IBAN': 'IBAN_CODE', 'IBAN_CODE': 'IBAN_CODE', 'SSN': 'US_SSN', 'US_SSN': 'US_SSN', 'AGE': 'AGE', 'NORP': 'NRP', 'ID': 'ID', 'AMOUNT': 'O', 'USERNAME': 'O', 'JOBTITLE': 'O', 'JOBAREA': 'O', 'ACCOUNTNAME': 'O', 'ACCOUNTNUMBER': 'O', 'JOBTYPE': 'O', 'BUILDINGNUMBER': 'O', 'CURRENCYSYMBOL': 'O', 'PASSWORD': 'O', 'SEX': 'O', 'GENDER': 'O', 'BITCOINADDRESS': 'O', 'MASKEDNUMBER': 'O', 'USERAGENT': 'O', 'CURRENCY': 'O', 'ETHEREUMADDRESS': 'O', 'NEARBYGPSCOORDINATE': 'O', 'CREDITCARDISSUER': 'O', 'ORDINALDIRECTION': 'O', 'MAC': 'O', 'VEHICLEVRM': 'O', 'EYECOLOR': 'O', 'CREDITCARDCVV': 'O', 'HEIGHT': 'O', 'LITECOINADDRESS': 'O', 'VEHICLEVIN': 'O', 'CURRENCYCODE': 'O', 'CURRENCYNAME': 'O', 'BIC': 'O', 'PIN': 'O', 'O': 'O'}
# Running model transformers_model on dataset...
# c:\Users\WIN10\AppData\Local\pypoetry\Cache\virtualenvs\presidio-evaluator-IFEnQHLa-py3.12\Lib\site-packages\transformers\pipelines\token_classification.py:393: UserWarning:
#
# Tokenizer does not support real words, using fallback heuristic
# Finished running model on dataset
# saving experiment data to experiment_20241119-225354.json

# %%
plotter.plot_scores()
